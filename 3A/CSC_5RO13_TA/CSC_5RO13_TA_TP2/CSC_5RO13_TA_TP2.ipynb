# %% [markdown]
# # CSC_5RO13_TA_TP2

# %% [markdown]
# In this practical work, you will manipulate the Segment Anything[1] API of Meta.

# %% [markdown]
# ## API

# %% [markdown]
# Go to the Github page of the project:\
# https://github.com/facebookresearch/segment-anything.git

# %% [markdown]
# Follow the guidelines to be able to render outputs for a given image.\
# You can experiment on a small part of the SAM Dataset that you can find here:\
# https://drive.google.com/drive/folders/1FCsy7yqoDoP_R1z7yTzgyvRqUs8rx17e?usp=sharing

# %%
import cv2
import os
import sys

sys.path.append(os.path.join(os.getcwd(), "segment_anything"))

from segment_anything import SamAutomaticMaskGenerator, sam_model_registry

sam = sam_model_registry["default"](checkpoint="./sam_vit_h_4b8939.pth")
mask_generator = SamAutomaticMaskGenerator(sam)
masks = mask_generator.generate(cv2.imread("./images/sa_815.jpg"))
# Out:
# /home/trofino/git_repositories/classes_ensta/3A/CSC_5RO13_TA/CSC_5RO13_TA_TP2/segment_anything/segment_anything/build_sam.py:105: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental featur
# ...

# %% [markdown]
# it was necessary to install `torch` and `torchvision` with:
# ```bash
# pip install torch torchvision
# ```

# %% [markdown]
# Render the results for a couple of images.\
# Pay attention to the different components of the outputs. What are they?\
# What are the classes that are part of the model prediction?\
# What other insights does the model provide?

# %% [markdown]
# ## SAM

# %% [markdown]
# You will use SAM as a zero-shot prediction tool on an unseen dataset to generate the semantic segmentation ground truth.\
# To do so, we will use the INFRAPARIS Dataset[2] that can be found here:\
# https://drive.google.com/drive/folders/1WMErTgOy4WcBJJzTKmRLz72eTr38tmFB?usp=sharing

# %% [markdown]
# Use SAM on raw images to get the associated semantic segmentation maps. You don't need to predict all classes. Choose just a  couple of them.
# Even though INFRAPARIS provides ground truth annotations, we will train a model on the pseudo-ground-truth generated by SAM to challenge its generalization power.

# %% [markdown]
# ## SAM U-Net

# %% [markdown]
# Once you have your training dataset all set, train a U-Net on it:\
# https://github.com/milesial/Pytorch-UNet.git

# %% [markdown]
# Please do not use the ground truth of INFRAPARIS for training. You only use them to test the performance of the model trained on the SAM predictions.

# %% [markdown]
# What metrics are relevant in our case. Give the results and compare to the performance of a model trained on the INFRAPARIS annotations. Is the difference significant? What can you conclude regarding the generalization power of SAM?
